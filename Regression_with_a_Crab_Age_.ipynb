# %% [markdown]
# <a href="https://colab.research.google.com/github/sumaia42/Machine_Learning/blob/main/Regression_with_a_Crab_Age_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/content/train.csv')
df.head()
# Out:
#    id Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0   0   I  1.5250    1.1750  0.3750  28.973189       12.728926
# 1   1   I  1.1000    0.8250  0.2750  10.418441        4.521745
# 2   2   M  1.3875    1.1125  0.3750  24.777463       11.339800
# 3   3   F  1.7000    1.4125  0.5000  50.660556       20.354941
# 4   4   I  1.2500    1.0125  0.3375  23.289114       11.977664
#
#    Viscera Weight  Shell Weight  Age
# 0        6.647958      8.348928    9
# 1        2.324659      3.401940    8
# 2        5.556502      6.662133    9
# 3       10.991839     14.996885   11
# 4        4.507570      5.953395    8

# %%
df.Sex.value_counts()
# Out:
# M    27084
# I    23957
# F    23010
# Name: Sex, dtype: int64

# %%
df.replace({'Sex': {'M':2,'I':1,'F':0}},inplace=True)

# %%
df.head()
# Out:
#    id  Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0   0    1  1.5250    1.1750  0.3750  28.973189       12.728926
# 1   1    1  1.1000    0.8250  0.2750  10.418441        4.521745
# 2   2    2  1.3875    1.1125  0.3750  24.777463       11.339800
# 3   3    0  1.7000    1.4125  0.5000  50.660556       20.354941
# 4   4    1  1.2500    1.0125  0.3375  23.289114       11.977664
#
#    Viscera Weight  Shell Weight  Age
# 0        6.647958      8.348928    9
# 1        2.324659      3.401940    8
# 2        5.556502      6.662133    9
# 3       10.991839     14.996885   11
# 4        4.507570      5.953395    8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74051 entries, 0 to 74050
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              74051 non-null  int64
#  1   Sex             74051 non-null  int64
#  2   Length          74051 non-null  float64
#  3   Diameter        74051 non-null  float64
#  4   Height          74051 non-null  float64
#  5   Weight          74051 non-null  float64
#  6   Shucked Weight  74051 non-null  float64
#  7   Viscera Weight  74051 non-null  float64
#  8   Shell Weight    74051 non-null  float64
#  9   Age             74051 non-null  int64
# dtypes: float64(7), int64(3)
# memory usage: 5.6 MB

# %%
X=df.drop(['id','Age'],axis=1)
y=df['Age']

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2,random_state=2529)

# %%
Xtrain.shape,Xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((59240, 8), (14811, 8), (59240,), (14811,))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(Xtrain,ytrain)
# Out:
# LinearRegression()

# %%
predictions = model.predict(Xtest)

# %%
predictions
# Out:
# array([ 9.52269806, 10.73874573,  7.06309243, ...,  6.15920255,
#        12.47390517, 11.02865037])

# %%
model.score(Xtest,ytest)
# Out:
# 0.5382632597882826

# %% [markdown]
# test value

# %%
df1= pd.read_csv('/content/test.csv')
df1.head()
# Out:
#       id Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0  74051   I  1.0500    0.7625  0.2750   8.618248        3.657085
# 1  74052   I  1.1625    0.8875  0.2750  15.507176        7.030676
# 2  74053   F  1.2875    0.9875  0.3250  14.571643        5.556502
# 3  74054   F  1.5500    0.9875  0.3875  28.377849       13.380964
# 4  74055   I  1.1125    0.8500  0.2625  11.765042        5.528153
#
#    Viscera Weight  Shell Weight
# 0        1.729319      2.721552
# 1        3.246018      3.968930
# 2        3.883882      4.819415
# 3        6.548735      7.030676
# 4        2.466407      3.331066

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49368 entries, 0 to 49367
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              49368 non-null  int64
#  1   Sex             49368 non-null  object
#  2   Length          49368 non-null  float64
#  3   Diameter        49368 non-null  float64
#  4   Height          49368 non-null  float64
#  5   Weight          49368 non-null  float64
#  6   Shucked Weight  49368 non-null  float64
#  7   Viscera Weight  49368 non-null  float64
#  8   Shell Weight    49368 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 3.4+ MB

# %%
df1.replace({'Sex':{'M':2,'I':1,'F':0}},inplace=True)

# %%
df1
# Out:
#            id  Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0       74051    1  1.0500    0.7625  0.2750   8.618248        3.657085
# 1       74052    1  1.1625    0.8875  0.2750  15.507176        7.030676
# 2       74053    0  1.2875    0.9875  0.3250  14.571643        5.556502
# 3       74054    0  1.5500    0.9875  0.3875  28.377849       13.380964
# 4       74055    1  1.1125    0.8500  0.2625  11.765042        5.528153
# ...       ...  ...     ...       ...     ...        ...             ...
# 49363  123414    0  1.3000    1.0375  0.3250  16.315137        6.690482
# 49364  123415    1  1.0375    0.7625  0.2625  10.276694        4.436697
# 49365  123416    0  1.4875    1.1625  0.3625  31.382897       11.396499
# 49366  123417    0  1.2375    0.9500  0.2875  15.663099        6.095142
# 49367  123418    2  1.6625    1.3000  0.4375  36.613379       14.911837
#
#        Viscera Weight  Shell Weight
# 0            1.729319      2.721552
# ...

# %%
df1['Age']=model.predict(df1.drop(['id'],axis=1))

# %%
df1
# Out:
#            id  Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0       74051    1  1.0500    0.7625  0.2750   8.618248        3.657085
# 1       74052    1  1.1625    0.8875  0.2750  15.507176        7.030676
# 2       74053    0  1.2875    0.9875  0.3250  14.571643        5.556502
# 3       74054    0  1.5500    0.9875  0.3875  28.377849       13.380964
# 4       74055    1  1.1125    0.8500  0.2625  11.765042        5.528153
# ...       ...  ...     ...       ...     ...        ...             ...
# 49363  123414    0  1.3000    1.0375  0.3250  16.315137        6.690482
# 49364  123415    1  1.0375    0.7625  0.2625  10.276694        4.436697
# 49365  123416    0  1.4875    1.1625  0.3625  31.382897       11.396499
# 49366  123417    0  1.2375    0.9500  0.2875  15.663099        6.095142
# 49367  123418    2  1.6625    1.3000  0.4375  36.613379       14.911837
#
#        Viscera Weight  Shell Weight        Age
# 0            1.729319      2.721552   8.063503
# ...
